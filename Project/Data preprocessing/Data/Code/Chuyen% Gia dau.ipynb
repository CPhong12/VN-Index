# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# Load the Excel file
excel_file = 'C:\Code\VN-Index\Raw Data\Giá dầu theo tháng.xlsx'

# Chỉ đọc một số hàng cụ thể, ví dụ từ hàng 5 đến hàng 15
df = pd.read_excel(excel_file, skiprows=5, nrows=20)

# Save to CSV
csv_file = 'C:\Code\VN-Index\Project\Data preprocessing\Data\Data_preprocessing\Giadau.csv'
df.to_csv(csv_file, index=False,encoding='utf-8')

print(f"Hàng đã chọn từ {excel_file} đã được chuyển đổi thành {csv_file}")
# Out:
# Hàng đã chọn từ C:\Code\VN-Index\Raw Data\Giá dầu theo tháng.xlsx đã được chuyển đổi thành C:\Code\VN-Index\Project\Data preprocessing\Data\Data_preprocessing\Giadau.csv

# %%
import pandas as pd

csv_file = 'C:\Code\VN-Index\Project\Data preprocessing\Data\Data_preprocessing\Giadau.csv'
df = pd.read_csv(csv_file)

df_dropped = df.drop(df.index[0:6].tolist() + df.index[7:40].tolist())

output_file = 'C:\Code\VN-Index\Project\Data preprocessing\Data\Data_preprocessing\Giá dầu.csv'
df_dropped.to_csv(output_file, index=False, encoding='utf-8')

print(f"các hàng cần lấy lưu trong {output_file}")
# Out:
# các hàng cần lấy lưu trong C:\Code\VN-Index\Project\Data preprocessing\Data\Data_preprocessing\Giá dầu.csv

# %%
df= pd.read_csv('C:\Code\VN-Index\Project\Data preprocessing\Data\Data_preprocessing\Giá dầu.csv')
df
# Out:
#   Chỉ tiêu Đơn vị tính  Tháng 1/2013  Tháng 2/2013  Tháng 3/2013  \
# 0  Dầu thô   Triệu USD         662.0         487.0         634.0
#
#    Tháng 4/2013  Tháng 5/2013  Tháng 6/2013  Tháng 7/2013  Tháng 8/2013  ...  \
# 0         533.0         642.0         677.0         599.0         643.0  ...
#
#    Tháng 11/2023  Tháng 12/2023  Tháng 1/2024  Tháng 2/2024  Tháng 3/2024  \
# 0          194.0          122.0         143.0         104.0         270.0
#
#    Tháng 4/2024  Tháng 5/2024  Tháng 6/2024  Tháng 7/2024  Tháng 8/2024
# 0         313.0         238.0          35.0          51.0          48.0
#
# [1 rows x 142 columns]

# %%
import pandas as pd

file_path = 'C:\Code\VN-Index\Project\Data preprocessing\Data\Data_preprocessing\Giá dầu.csv' 
df = pd.read_csv(file_path)

# Reshape the dataframe using melt
df_long = df.melt(id_vars=["Chỉ tiêu", "Đơn vị tính"], var_name="Date", value_name="Value")

# Save the reshaped data to a new CSV file
df_long.to_csv('C:\Code\VN-Index\Project\Data preprocessing\Data\Data_preprocessing\Giá dầu.csv', index=False)

# Print the reshaped dataframe
print(df_long)
# Out:
#     Chỉ tiêu Đơn vị tính          Date  Value
# 0    Dầu thô   Triệu USD  Tháng 1/2013  662.0
# 1    Dầu thô   Triệu USD  Tháng 2/2013  487.0
# 2    Dầu thô   Triệu USD  Tháng 3/2013  634.0
# 3    Dầu thô   Triệu USD  Tháng 4/2013  533.0
# 4    Dầu thô   Triệu USD  Tháng 5/2013  642.0
# ..       ...         ...           ...    ...
# 135  Dầu thô   Triệu USD  Tháng 4/2024  313.0
# 136  Dầu thô   Triệu USD  Tháng 5/2024  238.0
# 137  Dầu thô   Triệu USD  Tháng 6/2024   35.0
# 138  Dầu thô   Triệu USD  Tháng 7/2024   51.0
# 139  Dầu thô   Triệu USD  Tháng 8/2024   48.0
#
# [140 rows x 4 columns]

# %%
df = pd.read_csv('C:\Code\VN-Index\Project\Data preprocessing\Data\Data_preprocessing\Giá dầu.csv')
print(df.columns)
# Out:
# Index(['Chỉ tiêu', 'Đơn vị tính', 'Date', 'Value'], dtype='object')

# %%
import pandas as pd

# Bước 1: Đọc dữ liệu từ file CSV (nếu chưa làm)
file_path = 'C:\Code\VN-Index\Project\Data preprocessing\Data\Data_preprocessing\Giá dầu.csv'  # Thay thế đường dẫn của bạn
df = pd.read_csv(file_path)

# Bước 2: Xóa cột 'Đơn vị tính'
df = df.drop(columns=['Đơn vị tính'])

# Bước 3: Tính phần trăm giá trị của mỗi hàng so với hàng trước đó
df['% Value'] = df['Value']  # Tạo cột mới '% Value'
for i in range(1, len(df)):
    df['% Value'].iloc[i] = (df['Value'].iloc[i] * 100) / df['Value'].iloc[i - 1]

# Bước 4: Gán giá trị của hàng đầu tiên thành 100% (vì không có giá trị tháng trước để so sánh)
df['% Value'].iloc[0] = 100

# Bước 5: Làm tròn giá trị '% Value' đến 2 chữ số thập phân
df['% Value'] = df['% Value'].round(2)
df = df.drop(columns=['Value'])
df = df.rename(columns={'% Value':'Value'})
# Bước 6: Hiển thị kết quả
print(df)

# Bước 7: Lưu lại nếu cần
df.to_csv('C:\Code\VN-Index\Project\Data preprocessing\Data\Data_preprocessing\Giá dầu(%).csv', index=False)
# Out:
#     Chỉ tiêu          Date   Value
# 0    Dầu thô  Tháng 1/2013  100.00
# 1    Dầu thô  Tháng 2/2013   73.56
# 2    Dầu thô  Tháng 3/2013  130.18
# 3    Dầu thô  Tháng 4/2013   84.07
# 4    Dầu thô  Tháng 5/2013  120.45
# ..       ...           ...     ...
# 135  Dầu thô  Tháng 4/2024  115.93
# 136  Dầu thô  Tháng 5/2024   76.04
# 137  Dầu thô  Tháng 6/2024   14.71
# 138  Dầu thô  Tháng 7/2024  145.71
# 139  Dầu thô  Tháng 8/2024   94.12
#
# [140 rows x 3 columns]
# C:\Users\acer\AppData\Local\Temp\ipykernel_18672\1419843150.py:13: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# ...
